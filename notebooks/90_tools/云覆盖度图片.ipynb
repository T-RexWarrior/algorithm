# %%
import torch

print(f"PyTorch 版本: {torch.__version__}")
print(f"是否可以使用 GPU 加速: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"检测到的显卡名称: {torch.cuda.get_device_name(0)}")
else:
    print("未能检测到 GPU，请检查 CUDA 或驱动配置。")
# Out:
# PyTorch 版本: 2.5.1
# 是否可以使用 GPU 加速: True
# 检测到的显卡名称: NVIDIA GeForce RTX 5060 Ti
