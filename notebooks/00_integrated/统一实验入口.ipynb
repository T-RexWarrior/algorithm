# %% [markdown]
# # GPP 统一实验入口
#
# 公共的数据清洗、站点划分、缩放、模型、训练、评估和检查点逻辑已经移入 `src/gpp_inversion`。本 Notebook 只保留配置与调用。历史 Notebook 不会被覆盖。

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / 'pyproject.toml').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / 'pyproject.toml').exists():
    raise RuntimeError('没有找到项目根目录 pyproject.toml')
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
PROJECT_ROOT

# %% [markdown]
# ## 1. 准备配置
# 复制 `configs/experiment.example.json`，填写真实数据路径、输出路径及互斥的训练/验证/测试站点。`model.kind` 可选 `tcn`、`mamba`、`neural_cde`；设置 `cross_validation.enabled=true` 可运行按地类分层的五折站点验证。

# %%
from gpp_inversion import ExperimentConfig

CONFIG_PATH = PROJECT_ROOT / 'configs' / 'experiment.example.json'
config = ExperimentConfig.from_json(CONFIG_PATH)
config

# %% [markdown]
# ## 2. 运行实验
# 下面一行会完成站点互斥检查、训练集缩放器拟合、模型训练、最佳检查点恢复和评估。统一入口会保存实验清单/配置哈希、逐样本预测、逐站/地类/年度指标和 Notebook 风格的逐站诊断图。请先完成配置再执行。

# %%
from gpp_inversion import run_experiment

# result = run_experiment(config)
# result

# %% [markdown]
# ## 3. 查看统一评估产物
# 运行完成后可直接读取输出目录中的逐站指标和预测文件；图片位于 `evaluation/test_station_plots/`。交叉验证模式下，把下面的 `config.output_dir` 换成对应的 `fold_XX` 目录并读取 `val_*` 文件。

# %%
import pandas as pd

# station_metrics = pd.read_csv(config.output_dir / 'evaluation' / 'test_metrics_by_station.csv')
# predictions = pd.read_csv(config.output_dir / 'evaluation' / 'test_predictions.csv')
# display(station_metrics)
# predictions.head()
